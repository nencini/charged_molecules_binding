# %%
"""Jupyter Notebook to Analyze all the simulations"""


import sys
import numpy as np
import MDAnalysis as mda
import matplotlib.pyplot as plt
import os
import fnmatch
import yaml
import gc
from datetime import date
today = date.today()

gc.collect()
# Out:
# 0

# %%
folder_path="/media/nenciric/Ricky2020/simulations/"
systems=["dibucaine","etidocaine","SMS","TPP"]

# %%
def go_through_simulation(topology,trajectory,output,system,topology_tpr):

    u = mda.Universe(topology,trajectory)
          
    begin_time=u.trajectory.time

    sim={}
    sim['TRAJECTORY_SIZE'] = os.path.getsize(trajectory)/1048576

    Nframes=len(u.trajectory)
    timestep = u.trajectory.dt
    sim['TIMESTEP'] = timestep
    
    trj_length = Nframes * timestep
   
    sim['TRJLENGTH'] = trj_length
    sim['TRJBEGIN'] = begin_time
    sim['TRJEND'] = begin_time+trj_length
    sim['BINDINGEQ'] = input("Biding of {} eqilibrated after [ps] \n".format(output))

    
    #get temperature from tpr; taken from AddData.py by Anne Kiirikki
    file1 =  'temporary_tpr.txt'

    print("Exporting information with gmx dump")  

    os.system('echo System | gmx dump -s '+ topology_tpr + ' > '+file1)

    with open(file1, 'rt') as tpr_info:
        for line in tpr_info:
            if 'ref-t' in line:
                sim['TEMPERATURE']=float(line.split()[1])
    
    

        
    outfileDICT=folder_path + output + '/README.yaml'

    with open(outfileDICT, 'w') as f:
        yaml.dump(sim,f, sort_keys=False)
        
        
    with open(system + '.out', 'a') as f:
        f.write("{:70} {:>10} {:>10} {:>10} {:>10} {:>10} {:>10} {:>10.0f} \n".format(output,sim['TRJBEGIN']/1000,sim['TRJEND']/1000,timestep,sim['TRJLENGTH']/1000,sim['TEMPERATURE'],sim['BINDINGEQ'],sim['TRAJECTORY_SIZE']))
        
    print("great success!!!")
    
def initialize_output(system,folder_path):
    with open(system + '.out', 'w') as f:
        f.write("# List of simulations for: {} \n".format(system))
        f.write("# Path: {} \n".format(folder_path))
        f.write("# Create on: {} \n \n".format(today))
        f.write("#     1 - System \n")
        f.write("#     2 - Start time [ns] \n")
        f.write("#     3 - End time [ns] \n")
        f.write("#     4 - Time step [ps]  \n")
        f.write("#     5 - Total length [ns] \n")
        f.write("#     6 - Temperature  \n")
        f.write("#     7 - Binding equilibrated after [ps] \n")
        f.write("#     8 - Trajectory size [MB] \n \n")

        
"""Analysis of different stuff - to be developed"""
def box_dimensions(topology,trajectory,output,system):
    
    u = mda.Universe(topology,trajectory)
    box_sizes=[]
    
    """Go through the simulation - do I want this???, gets APL as a function of time"""
    for ts in u.trajectory:
        #count the index of the frame, numbered from 0, 
        frame = ts.frame  

            
        #reads the dimension (in Angstroms)
        current_box_z = ts.dimensions[2]
        current_box_x = ts.dimensions[0]
          
        last_time = ts.time

            
        box_sizes.append([last_time,current_box_x/10,current_box_z/10])

        
    with open(output+'_boxSizes.out', 'w') as f:
        np.savetxt(f, box_sizes,fmt='%8.4f  %.8f %.8f')

# %%
for system in systems:
    initialize_output(system,folder_path)

# %%
for file in os.listdir(folder_path):
    input_corr_file = folder_path+os.fsdecode(file)
    for system in systems:
        if fnmatch.fnmatch(os.fsdecode(file), "*"+system+"*"):
            print(os.fsdecode(file))

            topology = input_corr_file + '/' + os.fsdecode(file) + '.gro'
            topology_tpr = input_corr_file + '/' + os.fsdecode(file) + '.tpr'
            trajectory = input_corr_file + '/' + os.fsdecode(file) + '.xtc'
        
            go_through_simulation(topology,trajectory,os.fsdecode(file),system,topology_tpr)
# Out:
# dibucaine_POPC_CHARMM_298K_Cl_countra_104mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_104mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_123mM
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_123mM eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_130mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_130mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_13mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_13mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_156mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_156mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_15mM_177600waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_15mM_177600waters eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_182mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_182mM_8800waters eqilibrated after [ps]
# 100000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_208mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_208mM_8800waters eqilibrated after [ps]
# 150000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_234mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_234mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_260mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_260mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_26mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_26mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_286mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_286mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_312mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_312mM_8800waters eqilibrated after [ps]
# 20000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_52mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_52mM_8800waters eqilibrated after [ps]
# 100000
# Exporting information with gmx dump
# great success!!!
# dibucaine_POPC_CHARMM_298K_Cl_countra_78mM_8800waters
# Biding of dibucaine_POPC_CHARMM_298K_Cl_countra_78mM_8800waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_1302
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_1302 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_ECC
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_ECC eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_ECC_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_ECC_overbind eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem_overbind eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_5200waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_5200waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_5200waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_5200waters_paramchem eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_30mM_8800waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_30mM_8800waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_1212
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_1212 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_overbind eqilibrated after [ps]
# 1000000
# Exporting information with gmx dump
# great success!!!
# SMS_based_PEP1_POPC_298K_Cl_countra_80mM_16000waters
# Biding of SMS_based_PEP1_POPC_298K_Cl_countra_80mM_16000waters eqilibrated after [ps]
# 250000
# Exporting information with gmx dump
# great success!!!
# SMS_based_PEP2_298K_200POPC_CHARMM36
# Biding of SMS_based_PEP2_298K_200POPC_CHARMM36 eqilibrated after [ps]
# 100000
# Exporting information with gmx dump
# great success!!!
# SMS_based_PEP3_298K_200POPC_CHARMM36
# Biding of SMS_based_PEP3_298K_200POPC_CHARMM36 eqilibrated after [ps]
# 300000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_12mM_9200waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_12mM_9200waters eqilibrated after [ps]
# 40000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_24mM_9200waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_24mM_9200waters eqilibrated after [ps]
# 140000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_33mM_10200waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_33mM_10200waters eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_40mM_25000waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_40mM_25000waters eqilibrated after [ps]
# 166900
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_40mM_25000waters_167
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_40mM_25000waters_167 eqilibrated after [ps]
# 2000000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_41mM_20000waters_overbind
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_41mM_20000waters_overbind eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_46mM_9600waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_46mM_9600waters eqilibrated after [ps]
# 150000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_58mM_9600waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_58mM_9600waters eqilibrated after [ps]
# 100000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_177600waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_177600waters eqilibrated after [ps]
# 414000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_paramchem eqilibrated after [ps]
# 1323000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_paramchem eqilibrated after [ps]
# 800000
# Exporting information with gmx dump
# great success!!!
# SMS_based_PEP1_POPC_298K_Cl_countra_40mM
# Biding of SMS_based_PEP1_POPC_298K_Cl_countra_40mM eqilibrated after [ps]
# 700000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_70mM_9600waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_70mM_9600waters eqilibrated after [ps]
# 190000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_214mM_5200waters
# Biding of TPP_POPC_CHARMM36_298K_214mM_5200waters eqilibrated after [ps]
# 130000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_177600waters_413
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_177600waters_413 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_19900waters_paramchem_ECC
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_19900waters_paramchem_ECC eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters eqilibrated after [ps]
# 800000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_2
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_2 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_2746
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_2746 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_overbind eqilibrated after [ps]
# 1000000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_paramchem eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_paramchem_1314
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_paramchem_1314 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_paramchem_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_20000waters_paramchem_overbind eqilibrated after [ps]
# 1300000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_5200waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_5200waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_5200waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_5200waters_paramchem eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_5985waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_5985waters eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_7581waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_7581waters eqilibrated after [ps]
# 550000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_9975waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_140mM_9975waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_1968mM_11252waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_1968mM_11252waters_paramchem eqilibrated after [ps]
# ?
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters eqilibrated after [ps]
# 900000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_2785
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_2785 eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_280mM_19900waters_overbind eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_82mM_9600waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_82mM_9600waters eqilibrated after [ps]
# 350000
# Exporting information with gmx dump
# great success!!!
# SMS_POPC_CHARMM_298K_Cl_countra_94mM_9600waters
# Biding of SMS_POPC_CHARMM_298K_Cl_countra_94mM_9600waters eqilibrated after [ps]
# ?
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_100mM_11000waters
# Biding of TPP_POPC_CHARMM36_298K_100mM_11000waters eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_107mM_5200waters
# Biding of TPP_POPC_CHARMM36_298K_107mM_5200waters eqilibrated after [ps]
# 0
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters_ECC
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters_ECC eqilibrated after [ps]
# 160000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_B3LYP_ESP_charges
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_B3LYP_ESP_charges eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_B3LYP_ESP_charges_ECC
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_B3LYP_ESP_charges_ECC eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_charges_Clarke
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_charges_Clarke eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_charges_Clarke_ECC
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters_paramchem_charges_Clarke_ECC eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_140mM_20000waters_swiss_charges_Clarke
# Biding of TPP_POPC_CHARMM36_298K_140mM_20000waters_swiss_charges_Clarke eqilibrated after [ps]
# ?
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_paramchem_1257
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_paramchem_1257 eqilibrated after [ps]
# ?wrong_tpr?
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_paramchem_overbind
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_19900waters_paramchem_overbind eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_5200waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_5200waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_5200waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_420mM_5200waters_paramchem eqilibrated after [ps]
# 50000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_560mM_5200waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_560mM_5200waters eqilibrated after [ps]
# 100000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_70mM_19900waters
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_70mM_19900waters eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_70mM_19900waters_paramchem
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_70mM_19900waters_paramchem eqilibrated after [ps]
# 1100000
# Exporting information with gmx dump
# great success!!!
# etidocaine_POPC_CHARMM_298K_Cl_countra_70mM_19900waters_paramchem_ECC
# Biding of etidocaine_POPC_CHARMM_298K_Cl_countra_70mM_19900waters_paramchem_ECC eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# SMS_based_PEP1_POPC_298K_Cl_countra_20mM
# Biding of SMS_based_PEP1_POPC_298K_Cl_countra_20mM eqilibrated after [ps]
# 390000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_280mM_20000waters
# Biding of TPP_POPC_CHARMM36_298K_280mM_20000waters eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_280mM_20000waters_ECC
# Biding of TPP_POPC_CHARMM36_298K_280mM_20000waters_ECC eqilibrated after [ps]
# 250000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_B3LYP_ESP_charges
# Biding of TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_B3LYP_ESP_charges eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_B3LYP_ESP_charges_ECC
# Biding of TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_B3LYP_ESP_charges_ECC eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_charges_Clarke
# Biding of TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_charges_Clarke eqilibrated after [ps]
# 200000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_charges_Clarke_ECC
# Biding of TPP_POPC_CHARMM36_298K_280mM_20000waters_paramchem_charges_Clarke_ECC eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_420mM_20000waters
# Biding of TPP_POPC_CHARMM36_298K_420mM_20000waters eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_420mM_20000waters_ECC
# Biding of TPP_POPC_CHARMM36_298K_420mM_20000waters_ECC eqilibrated after [ps]
# ?
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_B3LYP_ESP_charges
# Biding of TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_B3LYP_ESP_charges eqilibrated after [ps]
# 400000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_B3LYP_ESP_charges_ECC
# Biding of TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_B3LYP_ESP_charges_ECC eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_charges_Clarke
# Biding of TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_charges_Clarke eqilibrated after [ps]
# 600000
# Exporting information with gmx dump
# great success!!!
# TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_charges_Clarke_ECC
# Biding of TPP_POPC_CHARMM36_298K_420mM_20000waters_paramchem_charges_Clarke_ECC eqilibrated after [ps]
# 500000
# Exporting information with gmx dump
# great success!!!
